# %%
def Student():
  n = int(input("Input the number of student: "))
  for i in range(n):
    print("Give the student's information " + str(i+1))
    id = int(input("Input the student's Id "))
    name = str(input("Input the student's name "))
    DoB = str(input("Input the DoB of student "))
    Student.append([id, name, DoB])

# %%
def Course():
  a = int(input("Input the number of course: "))
  for b in range(a):
  print("Give the course's information " + str(b+1))
  id = int(input("Input the course's Id "))
  name = str(input("Input the course's name "))
  Course.append([id, name])

# %%
def Mark():
  c = int(input("Input the number of mark: "))
  for d in range(c):

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/practice.ipynb /content/Advanced-Programming-with-Python/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/practice.ipynb': No such file or directory

# %%
# !cp /content/practice.ipynb /content/Advanced-Programming-with-Python/
# Out:
# cp: cannot stat '/content/practice.ipynb': No such file or directory
